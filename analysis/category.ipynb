# %%
import pandas as pd

# %%
categories = pd.read_csv('category.csv')
categories.columns
# Out:
# Index(['카테고리', 'count'], dtype='object')

# %%
categories.drop(columns='count', inplace=True)

# %%
categories.to_csv('categories.csv', index=True)
