# %%
import pandas as pd


df = pd.read_csv("dataset/aladin/aladin_info_1.csv", index_col=False)

# None 값을 가진 행 찾기
none_rows = df[df['알라딘책소개'].isna()]

# 데이터프레임 출력 옵션 설정
pd.set_option('display.max_rows', None)  # 모든 행 표시
pd.set_option('display.max_columns', None)  # 모든 열 표시 
pd.set_option('display.width', None)  # 너비 제한 해제
pd.set_option('display.max_colwidth', None)  # 컬럼 너비 제한 해제


# None 값을 가진 행의 자료명 출력
print("\n'알라딘책소개'가 None인 도서 자료명:")
none_rows
# Out:
# C:\Users\yuni0\AppData\Local\Temp\ipykernel_41308\2179271716.py:4: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv("dataset/aladin/aladin_info_1.csv", index_col=False)
# '알라딘책소개'가 None인 도서 자료명:
#                                                                     자료명  \
# 12                                                              보건의료통계학
# 20                                              (기초부터 탄탄하게) 처음 듣는 의대 강의
# 21                                                    의대를 꿈꾸는 대한민국의 천재들
# 46                                                               이종욱 평전
# 60                                                                  괴물들
# 62                                                             언러키 스타트업
# 93                                                       식민지 청년 이봉창의 고백
# 94                                                                  박병선
# ...
